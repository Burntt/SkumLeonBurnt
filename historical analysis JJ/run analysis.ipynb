# %%
run analysis.py
# Out:
# trying
# token collected..
# collecting tweets..
# 603 tweets collected
# fetching historic price data..
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 59.0% complete
# 69.0% complete
# 79.0% complete
# 89.0% complete
# 99.0% complete
# historic data collected
# generating mean..
# mean_generated
# summarizing results..
# /Users/jurjenvangenugten/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# /Users/jurjenvangenugten/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:140: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/jurjenvangenugten/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_mstats_common.py:142: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
data = data.sort_values(by='mean (10 minutes)', ascending=False)
display(data)
#look at columns 'mean(10 minutes)' and 'max (10 minutes)' 
#those indicate the mean increase in % and the max increase in 5

#if tweet_count = 1 probably not very reliable
# Out:
#            username           target_id coin_symbol tweet_count  \
# 0         Elon Musk            44196397        DOGE           8
# 15      vitalik.eth           295218901        DOGE           1
# 8      CZ 🔶 Binance  902926941413453824         DOT           1
# 46  Richard Branson             8161232         ICX           1
# 54             CNBC            20402945         ICX           2
# ..              ...                 ...         ...         ...
# 63         Tim Cook          1636590253         ICX           1
# 58               ye           169686021         ICX           3
# 13      John McAfee           961445378         ICX           2
# 61     George Soros            23125257         BTC           1
# 57               ye           169686021         BNB           1
#
#    mean (10 minutes)    mean_std   mean_coef max (10 minutes)      max_std  \
# 0          0.0608359   0.0436702  0.00237826        0.0621693    0.0529499
# ...
